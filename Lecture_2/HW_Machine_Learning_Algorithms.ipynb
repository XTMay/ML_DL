# %% [markdown]
# <a href="https://colab.research.google.com/github/XTMay/ML_DL/blob/main/Lecture_2/HW_Machine_Learning_Algorithms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Machine Learning Algorithms Assignment
#
# ## Theory Questions 20 points (each question is worth 5 points)

# %% [markdown]
# #### Question 1. What is the main difference between supervised and unsupervised learning? Give an example of a supervised and unsupervised learning problem.

# %% [markdown]
# #### Answer:

# %% [markdown]
# #### Question 2. Describe the purpose of clustering algorithms in unsupervised learning. How does dimensionality reduction fit into unsupervised learning?

# %% [markdown]
# #### Answer:

# %% [markdown]
# #### Question 3. Define bias and variance in the context of machine learning models. Why is it important to strike a balance between bias and variance?

# %% [markdown]
# #### Answer:

# %% [markdown]
# #### Question 4. Analyze the model performance results to identify cases of underfitting, right fit, and overfitting.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Programming Questions (80 points)
# #### In this assignment, you are going to use dataset. This dataset is a great alternative to the widely used Iris dataset and contains data for three penguin species: Adélie, Chinstrap, and Gentoo1. We’ll follow these steps:
#
# - Data Loading and Exploration
# - Data Preprocessing
# - Model Selection and Training
# - Model Evaluation
# - Precision Percentage Calculation

# %% [markdown]
# #### Question 3. Define bias and variance in the context of machine learning models. Why is it important to strike a balance between bias and variance?

# %% [markdown]
# #### Before using the dataset you need to install its library first

# %%
pip install palmerpenguins
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split
from sklearn.pipeline import FeatureUnion, make_pipeline
from sklearn.metrics import confusion_matrix
### To deal with missing values
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ## Load Data

# %%
from palmerpenguins import load_penguins
penguins = load_penguins()

# %%
import pandas as pd
import seaborn as sns
from palmerpenguins import load_penguins
sns.set_style('whitegrid')

# %%
penguins = load_penguins()
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %% [markdown]
# ## Part 1: Explore the features (bill length, flipper length, etc.) and target variable (species) (20 points)

# %%
# TODO
g = sns.boxplot(x = 'island',
            y ='body_mass_g',
            hue = 'species',
            data = penguins,
            palette=['#FF8C00','#159090','#A034F0'],
            linewidth=0.3)
g.set_xlabel('Island')
g.set_ylabel('Body Mass')
# Out:
# Text(0, 0.5, 'Body Mass')

# %%
g = sns.lmplot(x="flipper_length_mm",
               y="body_mass_g",
               hue="species",
               height=7,
               data=penguins,
               palette=['#FF8C00','#159090','#A034F0'])
g.set_xlabels('Flipper Length')
g.set_ylabels('Body Mass')

# %% [markdown]
# ## Part 2: Data Preprocessing (10 points)

# %% [markdown]
# - Check for missing values and handle them (e.g., drop rows with NaN values).
#
# - Encode the species labels (Adélie, Chinstrap, Gentoo) into numerical values (0, 1, 2).

# %%
# TODO

# %% [markdown]
# ## Part 3: Model Selection and Training (30 points)

# %% [markdown]
# - Choose a machine learning model to deal with classification, such as Random Forest
#
# - Split the dataset into training and testing sets.
#
# - Train the model using the training data.

# %% [markdown]
# ### Random Forest

# %%
X,y = load_penguins(return_X_y = True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=100,
                                            random_state=0)

# %%
# TODO

# %%
y_pred = clf.predict(X_test)
print(confusion_matrix(y_test,y_pred,labels=['Adelie','Chinstrap','Gentoo']))

# %% [markdown]
# ## Part 4: Model Evaluation (20 points)

# %% [markdown]
# - Evaluate the model’s performance using metrics like accuracy, precision, recall, or F1-score.
#
# - Make predictions on the test data.
#
# - Analyze the performance of your model and determine whether it is a good fit or not. Provide an explanation in at least five sentences.

# %% [markdown]
# ### Precision Percentage Calculation:
#
# - Compare the predicted species with the original species labels.
#
# - Calculate the precision percentage based on correct predictions.

# %%
print(clf.score(X_test,y_test))
# Out:
# 0.96
